# %%
import seaborn as sns
df=sns.load_dataset("taxis")
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
print(df.shape)
# Out:
# (6433, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6433                           6433
# mean   2019-03-16 08:31:28.514223616  2019-03-16 08:45:49.491217408
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:50:34            2019-03-08 16:12:51
# 50%              2019-03-15 21:46:58            2019-03-15 22:06:44
# 75%              2019-03-23 17:41:38            2019-03-23 17:51:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# ...

# %%
df.describe(include="object")
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6433         6389            6407                   6388
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5451         4577             230                    245
#
#        pickup_borough dropoff_borough
# count            6407            6388
# unique              4               5
# top         Manhattan       Manhattan
# freq             5268            5206

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
((df.shape[0]-df.dropna().shape[0])/df.shape[0])*100
# Out:
# 1.4301259132597544

# %%
df=df.dropna()

# %%
df=df.reset_index(drop=True)

# %%
df.shape
# Out:
# (6341, 14)

# %%
df.describe()
# Out:
#                               pickup                        dropoff  \
# count                           6341                           6341
# mean   2019-03-16 08:30:26.574830080  2019-03-16 08:44:47.525784832
# min              2019-02-28 23:29:03            2019-02-28 23:32:35
# 25%              2019-03-08 15:28:20            2019-03-08 15:54:00
# 50%              2019-03-15 21:57:47            2019-03-15 22:07:48
# 75%              2019-03-23 17:45:29            2019-03-23 17:57:56
# max              2019-03-31 23:43:45            2019-04-01 00:13:58
# std                              NaN                            NaN
#
#         passengers     distance         fare          tip        tolls  \
# count  6341.000000  6341.000000  6341.000000  6341.000000  6341.000000
# mean      1.544078     2.997707    12.887931     1.972703     0.314793
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# ...

# %%
df.describe(include="object")
# Out:
#          color      payment     pickup_zone           dropoff_zone  \
# count     6341         6341            6341                   6341
# unique       2            2             194                    203
# top     yellow  credit card  Midtown Center  Upper East Side North
# freq      5373         4546             227                    244
#
#        pickup_borough dropoff_borough
# count            6341            6341
# unique              4               5
# top         Manhattan       Manhattan
# freq             5226            5172

# %%
df.isna().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %%
#EDA

# %%
#tip is the target column
#tip is a numerical feature,analyze with color feature of categorical data
df.color.value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %%
#graphical analyis of categorical
sns.barplot(x=df.color,y=df.tip,estimator='std')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
sns.barplot(x=df.color,y=df.tip,estimator='mean')
# Out:
# <Axes: xlabel='color', ylabel='tip'>

# %%
sns.histplot(x=df.tip,hue=df.color,kde=True,palette=['yellow','green'])
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# from the barplot we can observe that yellow taxis receive a higher average tip compared to green taxis.This suggests that customers tend to tip more, on average, when riding in yellow taxis than in green taxis
# the histogram visually confirms that yellow taxis not only receive higher average tips but also exhibit a wider range of tip values, including a greater proportion of larger tips, compared to green taxis.

# %% [markdown]
# **Hypothesis:**
#
# H0: distribution of tip for yellow=distribution of tip for green
#
# H1: distribution of tip for yellow != distribution of tip for green

# %%
yellow_tip=df['tip'][df['color']=='yellow']
green_tip=df['tip'][df['color']=='green']

# %%
green_tip.shape
# Out:
# (968,)

# %%
yellow_tip.shape
# Out:
# (5373,)

# %%
#Hypothesis Testing
# Independent T-Test
from scipy import stats

t_stat, p_val = stats.ttest_ind(yellow_tip,green_tip)
print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: The tip of yellow category is different that of green")
else:
    print("Fail to reject null hypothesis:")
# Out:
# Independent T-Test statistic: 17.05932566128597
# P-value: 7.791088119489451e-64
# Reject null hypothesis: The tip of yellow category is different that of green

# %%
#There is effect of color of tip column

# %%
df.payment.value_counts()
# Out:
# payment
# credit card    4546
# cash           1795
# Name: count, dtype: int64

# %%
sns.barplot(x=df.payment,y=df.tip,estimator='std')
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
sns.barplot(x=df.payment,y=df.tip,estimator='mean')
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(1, 3, figsize=(18, 5))

sns.barplot(x=df.payment, y=df.tip, estimator='std', ax=ax[0])
ax[0].set_title("Std of Tip by Payment")

sns.barplot(x=df.payment, y=df.tip, estimator='mean', ax=ax[1])
ax[1].set_title("Mean of Tip by Payment")

sns.histplot(x=df.tip, hue=df.payment, kde=True, ax=ax[2])
ax[2].set_title("Tip Distribution by Payment")

plt.tight_layout()
plt.show()

# %%
credit_tip=df['tip'][df['payment']=='credit card']
cash_tip=df['tip'][df['payment']=='cash']
print(credit_tip.shape)
print(cash_tip.shape)
# Out:
# (4546,)
# (1795,)

# %% [markdown]
# **Hypothesis:**
#
# H0: tip from credit card == cash
#
# H1: tip from credit card != cash

# %%
# Independent T-Test
t_stat, p_val = stats.ttest_ind(credit_tip, cash_tip)
print("Independent T-Test statistic:", t_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: The tip from credit card payment is different that of cash payment")
else:
    print("Fail to reject null hypothesis: No significant difference")
# Out:
# Independent T-Test statistic: 49.09538452722153
# P-value: 0.0
# Reject null hypothesis: The tip from credit card payment is different that of cash payment

# %%
df['pickup_borough'].unique()
# Out:
# array(['Manhattan', 'Queens', 'Bronx', 'Brooklyn'], dtype=object)

# %%
df['pickup_borough'].value_counts()
# Out:
# pickup_borough
# Manhattan    5226
# Queens        638
# Brooklyn      378
# Bronx          99
# Name: count, dtype: int64

# %%
sns.countplot(x=df['pickup_borough'],palette=['violet','black','yellow','red']) #univariate analysis
# Out:
# /tmp/ipython-input-2730329918.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['pickup_borough'],palette=['violet','black','yellow','red']) #univariate analysis
# <Axes: xlabel='pickup_borough', ylabel='count'>

# %%
sns.barplot(x=df['pickup_borough'],y=df['tip'],palette='Set2')
# Out:
# /tmp/ipython-input-2462997792.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'],y=df['tip'],palette='Set2')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
sns.barplot(x=df['pickup_borough'],y=df['tip'],palette='Set2',estimator='std')
# Out:
# /tmp/ipython-input-1152742515.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['pickup_borough'],y=df['tip'],palette='Set2',estimator='std')
# <Axes: xlabel='pickup_borough', ylabel='tip'>

# %%
df['tip'].groupby(df['pickup_borough']).mean()
# Out:
# pickup_borough
# Bronx        0.148586
# Brooklyn     0.979127
# Manhattan    1.945597
# Queens       3.066458
# Name: tip, dtype: float64

# %%
df['tip'].groupby(df['pickup_borough']).std()
# Out:
# pickup_borough
# Bronx        0.897261
# Brooklyn     1.674487
# Manhattan    1.997736
# Queens       4.323951
# Name: tip, dtype: float64

# %%
sns.histplot(hue=df['pickup_borough'],x=df['tip'],kde=True,bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# **Hypothesis:**
#
#
# *   H0: distribution of tip is the same across all pickup_borough categories
# *   H1: At least one category has a different distribution of tip

# %%
# ANOVA Test
manhattan_tip=df['tip'][df['pickup_borough']=='Manhattan']
queens_tip=df['tip'][df['pickup_borough']=='Queens']
Bronx_tip=df['tip'][df['pickup_borough']=='Bronx']
Brooklyn_tip=df['tip'][df['pickup_borough']=='Brooklyn']

f_stat, p_val = stats.f_oneway(manhattan_tip,queens_tip,Bronx_tip,Brooklyn_tip)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis:")
else:
    print("Fail to reject null hypothesis:")
# Out:
# ANOVA F-statistic: 91.5793383185057
# P-value: 5.155109332422435e-58
# Reject null hypothesis: Spending Score differs by Region

# %% [markdown]
# **Hypothesis:**
#
# *   H0: distribution of group1 == distribution of group 2
#
# *   H1: distribution of group1 != distribution of group 2

# %%
# Tukey HSD Test
from statsmodels.stats.multicomp import pairwise_tukeyhsd
# Perform Tukey HSD
tukey_result = pairwise_tukeyhsd(endog=df.tip, groups=df.pickup_borough, alpha=0.05)
print(tukey_result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1    group2  meandiff p-adj lower  upper  reject
# -------------------------------------------------------
#     Bronx  Brooklyn   0.8305 0.008 0.1595 1.5015   True
#     Bronx Manhattan    1.797   0.0  1.194    2.4   True
#     Bronx    Queens   2.9179   0.0 2.2759 3.5599   True
#  Brooklyn Manhattan   0.9665   0.0 0.6499  1.283   True
#  Brooklyn    Queens   2.0873   0.0 1.7016 2.4731   True
# Manhattan    Queens   1.1209   0.0 0.8716 1.3701   True
# -------------------------------------------------------

# %%
df['dropoff_borough'].value_counts()
# Out:
# dropoff_borough
# Manhattan        5172
# Queens            534
# Brooklyn          497
# Bronx             136
# Staten Island       2
# Name: count, dtype: int64

# %%
sns.countplot(x=df['dropoff_borough'],palette='Set2')
# Out:
# /tmp/ipython-input-3711686064.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['dropoff_borough'],palette='Set2')
# <Axes: xlabel='dropoff_borough', ylabel='count'>

# %%
sns.barplot(x=df['dropoff_borough'],y=df['tip'],estimator='mean',palette='Set2')
# Out:
# /tmp/ipython-input-1819909113.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['dropoff_borough'],y=df['tip'],estimator='mean',palette='Set2')
# <Axes: xlabel='dropoff_borough', ylabel='tip'>

# %%
sns.histplot(x=df['tip'],hue=df['dropoff_borough'],kde=True,bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
manhattan_tip=df['tip'][df['dropoff_borough']=='Manhattan']
queens_tip=df['tip'][df['dropoff_borough']=='Queens']
bronx_tip=df['tip'][df['dropoff_borough']=='Bronx']
brooklyn_tip=df['tip'][df['dropoff_borough']=='Brooklyn']
staten_tip=df['tip'][df['dropoff_borough']=='Staten Island']

# %%
# ANOVA Test
f_stat, p_val = stats.f_oneway(manhattan_tip,queens_tip,bronx_tip,brooklyn_tip,staten_tip)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis: Spending Score differs by Region")
else:
    print("Fail to reject null hypothesis: No significant difference by Region")
# Out:
# ANOVA F-statistic: 31.42417796696829
# P-value: 5.87859571331583e-26
# Reject null hypothesis: Spending Score differs by Region

# %%
# Tukey HSD Test
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# Perform Tukey HSD
tukey_result = pairwise_tukeyhsd(endog=df.tip, groups=df.dropoff_borough, alpha=0.05)
print(tukey_result)
# Out:
#      Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#   group1      group2    meandiff p-adj   lower   upper  reject
# --------------------------------------------------------------
#     Bronx      Brooklyn   1.3869    0.0  0.7691  2.0046   True
#     Bronx     Manhattan   1.4296    0.0  0.8751  1.9842   True
#     Bronx        Queens   1.8873    0.0  1.2742  2.5005   True
#     Bronx Staten Island  13.6303    0.0  9.0833 18.1773   True
#  Brooklyn     Manhattan   0.0427 0.9952 -0.2571  0.3425  False
#  Brooklyn        Queens   0.5004 0.0055  0.1026  0.8983   True
#  Brooklyn Staten Island  12.2434    0.0  7.7204 16.7664   True
# Manhattan        Queens   0.4577 0.0002  0.1675  0.7479   True
# Manhattan Staten Island  12.2007    0.0  7.6859 16.7154   True
#    Queens Staten Island   11.743    0.0  7.2206 16.2653   True
# --------------------------------------------------------------

# %%
df['pickup_zone'].value_counts()
# Out:
# pickup_zone
# Midtown Center                  227
# Penn Station/Madison Sq West    209
# Clinton East                    208
# Upper East Side South           208
# Midtown East                    196
#                                ...
# Ozone Park                        1
# Glendale                          1
# Woodlawn/Wakefield                1
# West Farms/Bronx River            1
# Hillcrest/Pomonok                 1
# Name: count, Length: 194, dtype: int64

# %%
df['dropoff_zone'].value_counts()
# Out:
# dropoff_zone
# Upper East Side North    244
# Murray Hill              217
# Midtown Center           215
# Midtown East             175
# Upper East Side South    173
#                         ...
# Queensboro Hill            1
# Homecrest                  1
# Madison                    1
# Morrisania/Melrose         1
# Brooklyn Navy Yard         1
# Name: count, Length: 203, dtype: int64

# %%
sns.countplot(x=df['pickup_zone'])
# Out:
# <Axes: xlabel='pickup_zone', ylabel='count'>

# %%
sns.countplot(x=df['dropoff_zone'])
# Out:
# <Axes: xlabel='dropoff_zone', ylabel='count'>

# %%
# ANOVA Test
regions = [group['tip'].values for name, group in df.groupby('pickup_zone')]
f_stat, p_val = stats.f_oneway(*regions)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis:")
else:
    print("Fail to reject null hypothesis:")
# Out:
# ANOVA F-statistic: 7.563376210961916
# P-value: 7.892434822136223e-169
# Reject null hypothesis:

# %%
# ANOVA Test
regions = [group['tip'].values for name, group in df.groupby('dropoff_zone')]
f_stat, p_val = stats.f_oneway(*regions)
print("ANOVA F-statistic:", f_stat)
print("P-value:", p_val)

if p_val < 0.05:
    print("Reject null hypothesis:")
else:
    print("Fail to reject null hypothesis:")
# Out:
# ANOVA F-statistic: 5.76903467327541
# P-value: 1.3107168403745948e-120
# Reject null hypothesis:

# %%
sns.histplot(df['tip'],kde=True)
plt.show()

# %%
sns.histplot(df['passengers'],kde=True)
plt.show()

# %%
sns.scatterplot(x=df.tip,y=df.passengers)
plt.show()

# %% [markdown]
# **Hypothesis for correlation for numeric variables**
#
# 1.   H0:correlation is zero
# 2.   H1: There is correlation

# %%
r,p_val=stats.spearmanr(df['tip'],df['fare'])
print("correlation",r)
print("P -value: ",p_val)
if p_val<0.05:
  print("Reject null hypothesis")
else:
  print("Reject alternate hypothesis")
# Out:
# correlation 0.310254279563729
# P -value:  1.5556730728881364e-141
# Reject null hypothesis

# %%
r,p_val=stats.spearmanr(df['tip'],df['passengers'])
print("correlation",r)
print("P -value: ",p_val)
if p_val<0.05:
  print("Reject null hypothesis")
else:
  print("Reject alternate hypothesis")
# Out:
# correlation 0.027509812818779178
# P -value:  0.028480753176042872
# Reject null hypothesis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6341 entries, 0 to 6340
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6341 non-null   datetime64[ns]
#  1   dropoff          6341 non-null   datetime64[ns]
#  2   passengers       6341 non-null   int64
#  3   distance         6341 non-null   float64
#  4   fare             6341 non-null   float64
#  5   tip              6341 non-null   float64
#  6   tolls            6341 non-null   float64
#  7   total            6341 non-null   float64
#  8   color            6341 non-null   object
#  9   payment          6341 non-null   object
#  10  pickup_zone      6341 non-null   object
#  11  dropoff_zone     6341 non-null   object
#  12  pickup_borough   6341 non-null   object
#  13  dropoff_borough  6341 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 693.7+ KB

# %%
sns.histplot(df['distance'],kde=True)
plt.show()

# %%
sns.scatterplot(x=df['tip'],y=df['distance'])
plt.show()

# %%
sns.histplot(df['tolls'],kde=True)
plt.show()

# %%
sns.scatterplot(x=df['tip'],y=df['tolls'])
plt.show()

# %%
sns.histplot(df['total'],kde=True)
plt.show()

# %%
sns.scatterplot(x=df['tip'],y=df['total'])
plt.show()

# %%
r,p_val=stats.spearmanr(df['tip'],df['distance'])
print("correlation",r)
print("P -value: ",p_val)
if p_val<0.05:
  print("Reject null hypothesis")
else:
  print("Reject alternate hypothesis")
# Out:
# correlation 0.29265085410043695
# P -value:  1.9411181331374707e-125
# Reject null hypothesis

# %%
r,p_val=stats.spearmanr(df['tip'],df['tolls'])
print("correlation",r)
print("P -value: ",p_val)
if p_val<0.05:
  print("Reject null hypothesis")
else:
  print("Reject alternate hypothesis")
# Out:
# correlation 0.175380002891528
# P -value:  5.643276180955435e-45
# Reject null hypothesis

# %%
r,p_val=stats.spearmanr(df['tip'],df['total'])
print("correlation",r)
print("P -value: ",p_val)
if p_val<0.05:
  print("Reject null hypothesis")
else:
  print("Reject alternate hypothesis")
# Out:
# correlation 0.5028299699182296
# P -value:  0.0
# Reject null hypothesis
